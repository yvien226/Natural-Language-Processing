# %% [markdown]
# # Enron email analysis
#
# The Enron email dataset contains approximately 500,000 emails generated by employees of the Enron Corporation. It was obtained by the Federal Energy Regulatory Commission during its investigation of Enron's collapse.
#
# In this example, we will use the first 1000 rows of email to perform sentiment analysis
#
# Data source: https://www.kaggle.com/datasets/wcukierski/enron-email-dataset

# %%
import os
import sys
import pandas as pd
import nltk
import spacy
import string
import email
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
# download spacy package
#!python -m spacy download en

# %%
# outputs
cols = ['subject', 'sender', 'receiver', 'body', 'tot_len', 'positive words', 'positive counts', 'negative words', 'negative counts']

output_name_xls ='enron_email_clean.xlsx'
output_name_csv ='enron_email_clean.csv'

# total numbers of email, specify None if want to read whole file
read_rows = 1000

# %%
# read emails data
data = pd.read_csv("data/emails.csv", encoding = "ISO-8859-1",  delimiter=',', nrows = read_rows)

# %%
data.shape
# Out:
# (1000, 2)

# %%
# create list of email objects
emails = list(map(email.parser.Parser().parsestr,data['message']))

# extract headings (eg: from, subject)
headings  = emails[0].keys()

# For each email, extract info for each key
for x in headings:
    data[x] = [doc[x] for doc in emails]

# %%
# check data
data.head(50)
# Out:
#                         file  \
# 0      allen-p/_sent_mail/1.
# 1     allen-p/_sent_mail/10.
# 2    allen-p/_sent_mail/100.
# 3   allen-p/_sent_mail/1000.
# 4   allen-p/_sent_mail/1001.
# 5   allen-p/_sent_mail/1002.
# 6   allen-p/_sent_mail/1003.
# 7   allen-p/_sent_mail/1004.
# 8    allen-p/_sent_mail/101.
# 9    allen-p/_sent_mail/102.
# 10   allen-p/_sent_mail/103.
# 11   allen-p/_sent_mail/104.
# 12   allen-p/_sent_mail/105.
# 13   allen-p/_sent_mail/106.
# 14   allen-p/_sent_mail/107.
# 15   allen-p/_sent_mail/108.
# 16   allen-p/_sent_mail/109.
# 17    allen-p/_sent_mail/11.
# 18   allen-p/_sent_mail/110.
# 19   allen-p/_sent_mail/111.
# 20   allen-p/_sent_mail/112.
# 21   allen-p/_sent_mail/113.
# 22   allen-p/_sent_mail/114.
# 23   allen-p/_sent_mail/115.
# 24   allen-p/_sent_mail/116.
# 25   allen-p/_sent_mail/117.
# 26   allen-p/_sent_mail/118.
# 27   allen-p/_sent_mail/119.
# 28    allen-p/_sent_mail/12.
# 29   allen-p/_sent_mail/120.
# 30   allen-p/_sent_mail/121.
# 31   allen-p/_sent_mail/122.
# 32   allen-p/_sent_mail/123.
# 33   allen-p/_sent_mail/124.
# 34   allen-p/_sent_mail/125.
# 35   allen-p/_sent_mail/126.
# 36   allen-p/_sent_mail/127.
# 37   allen-p/_sent_mail/128.
# 38   allen-p/_sent_mail/129.
# 39    allen-p/_sent_mail/13.
# 40   allen-p/_sent_mail/130.
# 41   allen-p/_sent_mail/131.
# 42   allen-p/_sent_mail/132.
# 43   allen-p/_sent_mail/133.
# 44   allen-p/_sent_mail/134.
# 45   allen-p/_sent_mail/135.
# 46   allen-p/_sent_mail/136.
# 47   allen-p/_sent_mail/137.
# 48   allen-p/_sent_mail/138.
# 49   allen-p/_sent_mail/139.
#
#                                               message  \
# 0   Message-ID: <18782981.1075855378110.JavaMail.e...
# 1   Message-ID: <15464986.1075855378456.JavaMail.e...
# 2
# 36                         muller@thedoghousemail.com
# 37                              kathy.moore@enron.com
# 38                            john.lavorato@enron.com
# 39                            james.steffes@enron.com
# 40                               cbpres@austin.rr.com
# 41                               pallen70@hotmail.com
# 42                               cbpres@austin.rr.com
# 43                                jsmith@austintx.com
# 44                                jsmith@austintx.com
# 45                         stagecoachmama@hotmail.com
# 46                                 bs_stone@yahoo.com
# 47                         stagecoachmama@hotmail.com
# 48  paul.lucci@enron.com, kenneth.shulklapper@enro...
# 49                              moshuffle@hotmail.com
#
#                                               Subject Mime-Version  \
# 0                                                              1.0
# 1                                                 Re:          1.0
# 2                                            Re: test          1.0
# 3                                                              1.0
# 4                                           Re: Hello          1.0
# 5                                           Re: Hello          1.0
# 6                                                              1.0
# 7                        Re: PRC review - phone calls          1.0
# 8                      Re: High Speed Internet Access          1.0
# 9   FW: fixed forward or other Collar floor gas pr...          1.0
# 10  Re: FW: fixed forward or other Collar floor ga...          1.0
# 11                                                             1.0
# 12        Consolidated positions: Issues & To Do list          1.0
# 13        Consolidated positions: Issues & To Do list          1.0
# 14                                                             1.0
# 15                               Re: 2001 Margin Plan          1.0
# 16               Var, Reporting and Resources Meeting          1.0
# 17                                                             1.0
# 18                                           Westgate          1.0
# 19         Meeting re: Storage Strategies in the West          1.0
# 20                                                             1.0
# 21                         Re: Not business related..          1.0
# 22                    Re: Original Sept check/closing          1.0
# 23                                     San Juan Index          1.0
# 24                                     San Juan Index          1.0
# 25                               Investment Structure          1.0
# 26                               Investment Structure          1.0
# 27                                                             1.0
# 28                                                             1.0
# 29                     Re: Gas Trading Vision meeting          1.0
# 30                                                             1.0
# 31                    Gas Physical/Financial Position          1.0
# 32                                            closing          1.0
# 33                                                             1.0
# 34                                                             1.0
# 35                                                             1.0
# 36                                                             1.0
# 37                                                             1.0
# 38                                                             1.0
# 39                                                             1.0
# 40                                                             1.0
# 41                Westgate Proforma-Phillip Allen.xls          1.0
# 42                                                             1.0
# 43                                                             1.0
# 44                                         Re: burnet          1.0
# 45                                                             1.0
# 46                                 Re: Sept 1 Payment          1.0
# 47                                                             1.0
# 48                        Contact list for mid market          1.0
# 49                                                             1.0
#
#                           Content-Type Content-Transfer-Encoding  \
# 0         text/plain; charset=us-ascii                      7bit
# 1         text/plain; charset=us-ascii                      7bit
# 2         text/plain; charset=us-ascii                      7bit
# 3         text/plain; charset=us-ascii                      7bit
# 4         text/plain; charset=us-ascii                      7bit
# 5         text/plain; charset=us-ascii                      7bit
# 6         text/plain; charset=us-ascii                      7bit
# 7         text/plain; charset=us-ascii                      7bit
# 8         text/plain; charset=us-ascii                      7bit
# 9         text/plain; charset=us-ascii                      7bit
# 10        text/plain; charset=us-ascii                      7bit
# 11        text/plain; charset=us-ascii                      7bit
# 12        text/plain; charset=us-ascii                      7bit
# 13        text/plain; charset=us-ascii                      7bit
# 14        text/plain; charset=us-ascii                      7bit
# 15        text/plain; charset=us-ascii                      7bit
# 16        text/plain; charset=us-ascii                      7bit
# 17        text/plain; charset=us-ascii                      7bit
# 18        text/plain; charset=us-ascii                      7bit
# 19        text/plain; charset=us-ascii                      7bit
# 20        text/plain; charset=us-ascii                      7bit
# 21        text/plain; charset=us-ascii                      7bit
# 22        text/plain; charset=us-ascii                      7bit
# 23        text/plain; charset=us-ascii                      7bit
# 24        text/plain; charset=us-ascii                      7bit
# 25        text/plain; charset=us-ascii                      7bit
# 26        text/plain; charset=us-ascii                      7bit
# 27        text/plain; charset=us-ascii                      7bit
# 28        text/plain; charset=us-ascii                      7bit
# 29        text/plain; charset=us-ascii                      7bit
# 30        text/plain; charset=us-ascii                      7bit
# 31        text/plain; charset=us-ascii                      7bit
# 32  text/plain; charset=ANSI_X3.4-1968                      7bit
# 33        text/plain; charset=us-ascii                      7bit
# 34        text/plain; charset=us-ascii                      7bit
# 35        text/plain; charset=us-ascii                      7bit
# 36        text/plain; charset=us-ascii                      7bit
# 37        text/plain; charset=us-ascii                      7bit
# 38        text/plain; charset=us-ascii                      7bit
# 39        text/plain; charset=us-ascii                      7bit
# 40        text/plain; charset=us-ascii                      7bit
# 41        text/plain; charset=us-ascii                      7bit
# 42        text/plain; charset=us-ascii                      7bit
# 43        text/plain; charset=us-ascii                      7bit
# 44        text/plain; charset=us-ascii                      7bit
# 45        text/plain; charset=us-ascii                      7bit
# 46        text/plain; charset=us-ascii                      7bit
# 47        text/plain; charset=us-ascii                      7bit
# 48        text/plain; charset=us-ascii                      7bit
# 49        text/plain; charset=us-ascii                      7bit
#
#              X-From                                               X-To X-cc  \
# 0   Phillip K Allen           Tim Belden <Tim Belden/Enron@EnronXGate>
# 1   Phillip K Allen  John J Lavorato <John J Lavorato/ENRON@enronXg...
# 2   Phillip K Allen                                   Leah Van Arsdall
# 3   Phillip K Allen                                      Randall L Gay
# 4   Phillip K Allen                                         Greg Piper
# 5   Phillip K Allen                                         Greg Piper
# 6   Phillip K Allen             david.l.johnson@enron.com, John Shafer
# 7   Phillip K Allen                                     Joyce Teixeira
# 8   Phillip K Allen                                         Mark Scott
# 9   Phillip K Allen                                    zimam@enron.com
# 10  Phillip K Allen  "Buckner, Buck" <buck.buckner@honeywell.com> @...
# 11  Phillip K Allen                         stagecoachmama@hotmail.com
# 12  Phillip K Allen                                        Keith Holst
# 13  Phillip K Allen                                        Keith Holst
# 14  Phillip K Allen                                   David W Delainey
# 15  Phillip K Allen                                       Paula Harris
# 16  Phillip K Allen                                         Ina Rangel
# 17  Phillip K Allen  Tim Heizenrader <Tim Heizenrader/Enron@EnronXG...
# 18  Phillip K Allen                               pallen70@hotmail.com
# 19  Phillip K Allen                                         Ina Rangel
# 20  Phillip K Allen                                 bs_stone@yahoo.com
# 21  Phillip K Allen       Steve Touchstone <STouchstone@natsource.com>
# 22  Phillip K Allen            "BS Stone" <bs_stone@yahoo.com> @ ENRON
# 30                   pallen.nsf
# 31                   pallen.nsf
# 32                   pallen.nsf
# 33                   pallen.nsf
# 34                   pallen.nsf
# 35                   pallen.nsf
# 36                   pallen.nsf
# 37                   pallen.nsf
# 38                   pallen.nsf
# 39  pallen (Non-Privileged).pst
# 40                   pallen.nsf
# 41                   pallen.nsf
# 42                   pallen.nsf
# 43                   pallen.nsf
# 44                   pallen.nsf
# 45                   pallen.nsf
# 46                   pallen.nsf
# 47                   pallen.nsf
# 48                   pallen.nsf
# 49                   pallen.nsf

# %%
# load spacy
spacy_nlp = spacy.load('en_core_web_sm')

# call the VADER object
analyser = SentimentIntensityAnalyzer()

# %% [markdown]
# # Functions

# %% [markdown]
# ### Identify sender and receiver

# %%
# identify Sender
def get_sender_name(sender):

    # get the first name and the full name
    if sender.find("@") > 0 :
        name = sender.split("@")[0]
        if name.find(".") > 0:
            sendername = name.split(".")[0] + " " + name.split(".")[1]
        else:
            sendername = name
    else:
        sendername = sender
    return sendername

# %%
# identify receiver
def get_receiver_name(receiver):
    
    try:

        # if there are multiple receiver
        if receiver.find(",") > 0:
            multi_receiver = receiver.split(",")
            receivername = ""
            for name in multi_receiver:
                if name.find("@") > 0:
                    name = name.split("@")[0]
                    
                    if name.find(".") > 0:
                        rname = name.split(".")[0] + " " + name.split(".")[1]
                    else:
                        rname = name
                else:
                    if name.find(".") > 0:
                        rname = name.split(".")[0] + " " + name.split(".")[1]
                    else:
                        rname = name.split("@")[0]
                receivername = receivername + rname + ", "
            receivername = receivername[:-2]
        else:
            # get the full name
            if receiver.find("@") > 0 :
                name = receiver.split("@")[0]
                
                if name.find(".") > 0:
                    receivername = name.split(".")[0] + " " + name.split(".")[1]
                else:
                    receivername = name
            else:
                receivername = receiver
    except:
        receivername = receiver
        
    return receivername

# %% [markdown]
# ### Extract body content

# %%
# get body content
def get_body_text(emails):
    email_text = []
    for email in emails.walk():
        if email.get_content_type() == 'text/plain':
            email_text.append(email.get_payload())
    return ''.join(email_text)

# %% [markdown]
# ### Remove signature

# %%
def remove_sign(body, sender_name):
    # if the sender's first name is in the body, remove it
    length_fnd = body.find(sender_name)
    if length_fnd > 0 :
        body_new = body[:length_fnd]
    else:
        body_new = body
    return body_new

# %% [markdown]
# ### Remove entities

# %%
# remove entities
def remove_entity(nlpdoc):
    doc_noentities = []

    ents = [e.text for e in nlpdoc.ents]
    newString = body_new
    for e in reversed(nlpdoc.ents): #reversed to not modify the offsets of other entities when substituting
        start = e.start_char
        end = start + len(e.text)
        newString = newString[:start] + '' + newString[end:]

    return newString

# %% [markdown]
# # Preprocessing
# Spacy? NLTK? BeautifulSoup for html? <br>
# see: http://ai.intelligentonlinetools.com/ml/sentiment-analysis
#
# Removal
# - remove entity (person, city names, geographical places
# - remove stopwords (I, is, you, we, for, and etc)
# - remove punctuation (!,_.?#;)
# - remove spaces
# - lemmatization
# https://medium.com/@makcedward/nlp-pipeline-stop-words-part-5-d6770df8a936

# %%
# Extract body from the email
data['Body'] = list(map(get_body_text, emails))

# %%
email_data_list = []

for ind, email in data.iterrows():
    # email data
    subject = email["Subject"]
    body = email["Body"]
    sender = email["From"]
    receiver = email["To"]
    
    # identify sender and receiver
    sender_name = get_sender_name(sender)
    receiver_name = get_receiver_name(receiver)
    

    # body text
    # remove signature
    body_new = remove_sign(body, sender_name)
    
    doc = spacy_nlp(body_new)
    
    # remove entities
    body_remove_ent = remove_entity(doc)
    
    doc = spacy_nlp(body_remove_ent)
    
    # get total length of the body
    tot_len = 0
    tot_len =len(doc)
    
    # lemmatization, remove stop words, spaces and punctuation
    # token.text = original text, token.lemma_ = lemmatization
    tokens = [token.lemma_ for token in doc if not token.is_stop | token.is_punct | token.is_space]
    
    # extract positive and negative words
    pos_word = ""
    neu_word = ""
    neg_word = ""
    pos = 0
    neu = 0
    neg = 0


    # scores each word
    for word in tokens:
        if(analyser.polarity_scores(word)['compound']) >= 0.05:
            pos_word = pos_word + word + ", "
            pos = pos + 1
        elif(analyser.polarity_scores(word)['compound']) <= -0.05:
            neg_word = neg_word + word + ", "
            neg = neg + 1
        else:
            neu_word = neu_word + word + ", "
            neu = neu + 1
        
            
    # append results
    email_data_list.append([subject, sender_name, receiver_name, body_new, tot_len, pos_word, pos, neg_word, neg])
    
#dataframe
email_data_df = pd.DataFrame(email_data_list, columns=cols)

# %%
# calculate the sentiment score using VADER
polarity = [round(analyser.polarity_scores(i)['compound'], 2) for i in email_data_df['body']]
email_data_df['sentiment_score'] = polarity

# determine overall sentiment based on the score
email_data_df['overall_sentiment'] = 'Neutral'
email_data_df.loc[email_data_df['sentiment_score'] > 0, 'overall_sentiment'] = 'Positive'
email_data_df.loc[email_data_df['sentiment_score'] < 0, 'overall_sentiment'] = 'Negative'

# %%
# check cleaned data 
email_data_df.head(5)
# Out:
#      subject         sender       receiver  \
# 0             phillip allen     tim belden
# 1        Re:  phillip allen  john lavorato
# 2   Re: test  phillip allen   leah arsdall
# 3             phillip allen    randall gay
# 4  Re: Hello  phillip allen     greg piper
#
#                                                 body  tot_len  \
# 0                          Here is our forecast\n\n         5
# 1  Traveling to have a business meeting takes the...      160
# 2                     test successful.  way to go!!!       10
# 3  Randy,\n\n Can you send me a schedule of the s...       41
# 4                Let's shoot for Tuesday at 11:45.          8
#
#                                  positive words  positive counts  \
# 0                                                              0
# 1  fun, honest, desire, stimulate, well, play,                 6
# 2                                  successful,                 1
# 3                                                              0
# 4                                                              0
#
#   negative words  negative counts  sentiment_score overall_sentiment
# 0                               0             0.00           Neutral
# 1                               0             0.93          Positive
# 2                               0             0.69          Positive
# 3                               0             0.00           Neutral
# 4        shoot,                 1            -0.34          Negative

# %% [markdown]
# ### save results into excel or csv

# %%
email_data_df.to_excel('output/' + output_name_xls , index=False)
email_data_df.to_csv('output/' + output_name_csv, index=False)
